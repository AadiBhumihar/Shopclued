# %%
import requests
from scrapy.http import TextResponse

# %%
res = requests.get('http://quotes.toscrape.com/page/1/')

# %%
res
# Out:
# <Response [200]>

# %%
response = TextResponse(res.url, body=res.text, encoding='utf-8')

# %%
response
# Out:
# <200 http://quotes.toscrape.com/page/1/>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>\n        <span>by <small class="author" itemprop="author">Albert Einstein</small>\n        <a href="/author/Albert-Einstein">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="change,deep-thoughts,thinking,world" /    > \n            \n            <a class="tag" href="/tag/change/page/1/">change</a>\n            \n            <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>\n            \n            <a class="tag" href="/tag/thinking/page/1/">thinking</a>\n            \n            <a class="tag" href="/tag/world/page/1/">world</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>\n        <span>by <small class="author" itemprop="author">J.K. Rowling</small>\n        <a href="/author/J-K-Rowling">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="abilities,choices" /    > \n            \n            <a class="tag" href="/tag/abilities/page/1/">abilities</a>\n            \n            <a class="tag" href="/tag/choices/page/1/">choices</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”</span>\n        <span>by <small class="author" itemprop="author">Albert Einstein</small>\n        <a href="/author/Albert-Einstein">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="inspirational,life,live,miracle,miracles" /    > \n            \n            <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>\n            \n            <a class="tag" href="/tag/life/page/1/">life</a>\n            \n            <a class="tag" href="/tag/live/page/1/">live</a>\n            \n            <a class="tag" href="/tag/miracle/page/1/">miracle</a>\n            \n            <a class="tag" href="/tag/miracles/page/1/">miracles</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”</span>\n        <span>by <small class="author" itemprop="author">Jane Austen</small>\n        <a href="/author/Jane-Austen">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="aliteracy,books,classic,humor" /    > \n            \n            <a class="tag" href= ...

# %%
response.css('title')
# Out:
# [<Selector xpath='descendant-or-self::title' data='<title>Quotes to Scrape</title>'>]

# %%
response.css('title::text').getall()
# Out:
# ['Quotes to Scrape']

# %%
response.css('title').getall()
# Out:
# ['<title>Quotes to Scrape</title>']

# %%
response.css('title::text')
# Out:
# [<Selector xpath='descendant-or-self::title/text()' data='Quotes to Scrape'>]

# %%
response.css('title::text').re(r'Quotes.*')
# Out:
# ['Quotes to Scrape']

# %%
response.css('title::text')
# Out:
# [<Selector xpath='descendant-or-self::title/text()' data='Quotes to Scrape'>]

# %%
response.css("div.quote")
# Out:
# [<Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' quote ')]" data='<div class="quote" itemscope itemtype="h'>,
#  <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' quote ')]" data='<div class="quote" itemscope itemtype="h'>,
#  <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' quote ')]" data='<div class="quote" itemscope itemtype="h'>,
#  <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' quote ')]" data='<div class="quote" itemscope itemtype="h'>,
#  <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' quote ')]" data='<div class="quote" itemscope itemtype="h'>,
#  <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' quote ')]" data='<div class="quote" itemscope itemtype="h'>,
#  <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' quote ')]" data='<div class="quote" itemscope itemtype="h'>,
#  <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' quote ')]" data='<div class="quote" itemscope itemtype="h'>,
#  <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' quote ')]" data='<div class="quote" itemscope itemtype="h'>,
#  <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' quote ')]" data='<div class="quote" itemscope itemtype="h'>]

# %%
quote = response.css("div.quote")[0]

# %%
quote
# Out:
# <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' quote ')]" data='<div class="quote" itemscope itemtype="h'>

# %%
quote.css("span.text::text").get()
# Out:
# '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”'

# %%
quote.css("small.author::text").get()
# Out:
# 'Albert Einstein'

# %%
quote.css("div.tags a.tag::text").getall()
# Out:
# ['change', 'deep-thoughts', 'thinking', 'world']

# %%
next_page = response.css('li.next a::attr(href)').get()

# %%
next_page
# Out:
# '/page/2/'

# %%
next_page = response.urljoin(next_page)

# %%
next_page
# Out:
# 'http://quotes.toscrape.com/page/2/'

# %%
response.css('.author + a::attr(href)')
# Out:
# [<Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' author ')]/following-sibling::*[name() = 'a' and (position() = 1)]/@href" data='/author/Albert-Einstein'>,
#  <Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' author ')]/following-sibling::*[name() = 'a' and (position() = 1)]/@href" data='/author/J-K-Rowling'>,
#  <Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' author ')]/following-sibling::*[name() = 'a' and (position() = 1)]/@href" data='/author/Albert-Einstein'>,
#  <Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' author ')]/following-sibling::*[name() = 'a' and (position() = 1)]/@href" data='/author/Jane-Austen'>,
#  <Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' author ')]/following-sibling::*[name() = 'a' and (position() = 1)]/@href" data='/author/Marilyn-Monroe'>,
#  <Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' author ')]/following-sibling::*[name() = 'a' and (position() = 1)]/@href" data='/author/Albert-Einstein'>,
#  <Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' author ')]/following-sibling::*[name() = 'a' and (position() = 1)]/@href" data='/author/Andre-Gide'>,
#  <Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' author ')]/following-sibling::*[name() = 'a' and (position() = 1)]/@href" data='/author/Thomas-A-Edison'>,
#  <Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' author ')]/following-sibling::*[name() = 'a' and (position() = 1)]/@href" data='/author/Eleanor-Roosevelt'>,
#  <Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' author ')]/following-sibling::*[name() = 'a' and (position() = 1)]/@href" data='/author/Steve-Martin'>]

# %%
rs = response.css('.author + a::attr(href)')[0]

# %%
rs
# Out:
# <Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' author ')]/following-sibling::*[name() = 'a' and (position() = 1)]/@href" data='/author/Albert-Einstein'>

# %%
rs = response.css('.author + a::attr(href)')[0].get()

# %%
rs
# Out:
# '/author/Albert-Einstein'

# %%
import requests
from scrapy.http import TextResponse
res = requests.get('https://www.shopclues.com/mobiles-smartphones.html')
response = TextResponse(res.url, body=res.text, encoding='utf-8')

# %%
res
# Out:
# <Response [200]>

# %%
response
# Out:
# <200 https://www.shopclues.com/mobiles-smartphones.html>

# %%
response.text
# Out:
# '\r\n<!DOCTYPE html>\r\n<html>\r\n<head>\r\n   <meta charset="utf-8">\r\n <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">\r\n <link rel="dns-prefetch" href="//ads.yahoo.com" />\r\n <!-- <link rel="dns-prefetch" href="//analytics.twitter.com" />-->\r\n <link rel="dns-prefetch" href="//api.targetingmantra.com" />\r\n <link rel="dns-prefetch" href="//api.apac-sg.zettata.com" />\r\n <link rel="dns-prefetch" href="//assets.adobedtm.com" />\r\n <link rel="dns-prefetch" href="//a.adroll.com" />\r\n <link rel="dns-prefetch" href="//cdn.atomex.net" />\r\n <link rel="dns-prefetch" href="//cdn.shopclues.net" />\r\n <link rel="dns-prefetch" href="//cdn.shopclues.com" />\r\n <link rel="dns-prefetch" href="//connect.facebook.net" />\r\n<!-- <link rel="dns-prefetch" href="//cluesnetwork.sc.omtrdc.net" />-->\r\n <link rel="dns-prefetch" href="//d.adroll.com" />\r\n <link rel="dns-prefetch" href="//datacdn.atomex.net" />\r\n <link rel="dns-prefetch" href="//dps.bing.com" />\r\n<!-- <link rel="dns-prefetch" href="//dpm.demdex.net" />-->\r\n <link rel="dns-prefetch" href="//dsp.send.microadinc.com" />\r\n <link rel="dns-prefetch" href="//facebook.com" />\r\n <link rel="dns-prefetch" href="//google.co.in" />\r\n <link rel="dns-prefetch" href="//google.com" />\r\n <link rel="dns-prefetch" href="//googleads.g.doubleclick.net" />\r\n <link rel="dns-prefetch" href="//googleadservices.com" />\r\n <link rel="dns-prefetch" href="//googletagservices.com" />\r\n <link rel="dns-prefetch" href="//gstatic.com" />\r\n <link rel="dns-prefetch" href="//ib.adnxs.com" />\r\n <link rel="dns-prefetch" href="//idsync.rlcdn.com" />\r\n <link rel="dns-prefetch" href="//partner.googleadservices.com" />\r\n <link rel="dns-prefetch" href="//pagead2.googlesyndication.com" />\r\n <link rel="dns-prefetch" href="//shopclues.com" />\r\n <link rel="dns-prefetch" href="//stats.g.doubleclick.net" />\r\n <link rel="dns-prefetch" href="//stats2.clicktracks.com" />\r\n <link rel="dns-prefetch" href="//t.mookie1.com" />\r\n <link rel="dns-prefetch" href="//tpc.googlesyndication.com" />\r\n <link rel="dns-prefetch" href="//us-u.openx.net" />\r\n <link rel="dns-prefetch" href="//x.bidswitch.net" />\r\n <link href=\'https://fonts.gstatic.com\' rel=\'preconnect\' crossorigin>\r\n <meta http-equiv="Content-Language" content="en" />\r\n   <title>Smartphones : Buy Wide Range Smartphones Online at Best Price on Shopclues.com : Mobile Phones</title>\r\n  \r\n        <meta name="Description" content="Choose from Wide Range of Smartphones Online at Best Prices in India. Get Free Shipping, Cash On Delivery, Cashback clues bucks on Eligible Purchases at Shopclues.com.Choose Shopclues for latest Gadgets as the perfect platform to grab your new smartphone "/>\r\n        <meta name="keywords" content="smartphones, buy smartphones online in india, shopclues.com"/>\r\n          <link href="https://www.shopclues.com/mobiles-smartphones.html?page=2" rel="next">\r\n             <link rel="canonical" href="https://www.shopclues.com/mobiles-smartphones.html" />\r\n           <link rel="alternate" media="handheld" href="https://m.shopclues.com/mobiles-smartphones.html"/>\r\n        <link rel="amphtml" href="https://m.shopclues.com/mobiles-smartphones.html/amp"/>\r\n         <link rel="alternate" href="android-app://com.shopclues/http/www.shopclues.com/mobiles-smartphones.html"/>\r\n        <meta name="robots" content="index,follow"/> \r\n <meta property="og:url" content="https://www.shopclues.com/mobiles-smartphones.html"/>\r\n<meta property="og:site_name" content="shopclues.com"/>\r\n\r\n<meta property="fb:app_id" content="233137156813679"/>\r\n\t\r\n    <meta property="og:description" content="Choose from Wide Range of Smartphones Online at Best Prices in India. Get Free Shipping, Cash On Delivery, Cashback clues bucks on Eligible Purchases at Shopclues.com.Choose Shopclues for latest Gadgets as the perfect platform to grab your new smartphone "/>\r ...

# %%
response.css("div.container").getall()
# Out:
# ['<div class="container">\r\n\t<div class="wrapper maxStWrap">\r\n\n \n<div class="breadcrums">    \n    <ul><li itemscope itemtype="http://data-vocabulary.org/Breadcrumb"><a itemprop="url" href="//www.shopclues.com/"><span itemprop="title">Home</span></a></li><li itemscope itemtype="http://data-vocabulary.org/Breadcrumb"><a itemprop="url" href="//www.shopclues.com/mobiles-and-tablets.html"><span itemprop="title">Mobiles &amp; Tablets</span></a></li><li>Smartphones</li></ul>    <!-- pin code div start -->\n                <div class="pin_location" style="display: none">\n               <p><!-- Your Pincode <span>122003</span> --><a href="javascript:void(0);" onclick="clp_public.toggle();">Change</a><a class="close" href="javascript:void(0);"></a></p> \n            </div>\n            <!-- pin code div end -->  \n    </div>\n\n<div class="cat_listing">\n              <div class="fltr_lft_pnl" style="float: left; width: 225px; margin-right: 20px; margin-bottom: 20px; background: #fff;">  \n            <div class="sng_block category_filter_list">\n    \n                    <div class="heading">Category Filters                      \n                                            <a class="toggle_arrow" href="javascript:void(0);"></a>\n                                          </div>\n    <div class="scrollable">\n        \n<ul class="filter-category">                <li data-seo="mobiles-and-tablets" class="">\n                                                                <a href="//www.shopclues.com/mobiles-and-tablets.html">\n                    <label>Mobiles &amp; Tablets</label></a>                       </li><li data-seo="mobiles-smartphones" class="selected child-one">\n                    <label>Smartphones</label></li>       </ul>\n</div>\n</div>\n<div class="sng_block category_filter_list" id="offers_category_tree">\n                    <div class="heading"> Offers <a class="toggle_arrow" href="javascript:void(0);"></a>\n   </div>\n    <div class="scrollable">\n        <ul class="filter-category" id="offr">\n                            <li data-seo="club-smartphone" class="child-two">\n                                                                <a href="//www.shopclues.com/club-smartphone.html">\n                    <label>Club Smartphone</label></a></li>                       <li data-seo="smartphone-mania" class="child-two">\n                                                                <a href="//www.shopclues.com/smartphone-mania.html">\n                    <label>Smartphone Mania</label></a></li>               </ul>\n        <script type="text/javascript">\n                if($("#offers_category_tree li").length==0){\n                    $("#offers_category_tree").remove();\n                }\n                                        \n                                            \n        </script>\n    </div>\n</div>            \n                <div class="sng_block left">\n        <div class="heading">Price            <a class="toggle_arrow" href="javascript:void(0);"></a><a class="clear" id="sort_price" href="javascript:void(0);">Clear All</a>\n        </div>\n         \n        <div class="scrollable">\n            <ul class="toggle scfilter" id="sort_price_fct" filtertype="S" filterid="sort_price">     \n\n                                                        <li>\n                                                                                                          \n      \n                                    <input type="checkbox" id="Rs. 2999 and Below" name="sort_price[]" value="0.00-2999.00" rev="sort_price" filtername="Price">\n\n                                    <!-- </span>  -->\n                                    <label for="Rs. 2999 and Below">\n                                        Rs. 2999 and Below (3)</label>\n                                </li>\n                                        \n                                                            <li>\n                           ...

# %%
response.body()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-751f817327c2> in <module>()
# ----> 1 response.body()
#
# TypeError: 'bytes' object is not callable

# %%
cont = response.css("div.container").getall()

# %%
sng = response.css("div.sng_block left").getall()
